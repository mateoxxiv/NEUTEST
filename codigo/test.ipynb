# %%
import get_values
obj = get_values.Calculate()
# Out:
# Total Consumption (EA): 18084652.75891
# Total Injection (EC): 39800.87496
# Total EE1: 1222.596
# Total EE2: 0.0
#            day  hour  consumption           ea  injection        ec  \
# 0   2023-09-01     0       55.725  32827.63105       0.00    0.0000
# 1   2023-09-01     1       63.960  37565.03340       0.00    0.0000
# 2   2023-09-01     2       62.751  36827.00167       0.00    0.0000
# 3   2023-09-01     3       58.887  34576.64009       0.00    0.0000
# 4   2023-09-01     4       51.376  30177.56102       0.00    0.0000
# 5   2023-09-01     5       41.525  24428.00035       0.00    0.0000
# 6   2023-09-01     6       48.594  28732.01228       0.00    0.0000
# 7   2023-09-01     7       66.131  38830.40327       0.22    5.2668
# 8   2023-09-01     8       55.098  32302.48586       2.38   56.9772
# 9   2023-09-01     9       35.022  20475.68444       4.82  115.3908
# 10  2023-09-01    10       26.824  15681.65308       4.19  100.3086
# ...

# %%
obj.imprimir()
# Out:
# Total Consumption (EA): 18084652.75891
# Total Injection (EC): 39800.87496
# Total EE1: 1222.596
# Total EE2: 0.0
#            day  hour  consumption           ea  injection        ec  \
# 0   2023-09-01     0       55.725  32827.63105       0.00    0.0000
# 1   2023-09-01     1       63.960  37565.03340       0.00    0.0000
# 2   2023-09-01     2       62.751  36827.00167       0.00    0.0000
# 3   2023-09-01     3       58.887  34576.64009       0.00    0.0000
# 4   2023-09-01     4       51.376  30177.56102       0.00    0.0000
# 5   2023-09-01     5       41.525  24428.00035       0.00    0.0000
# 6   2023-09-01     6       48.594  28732.01228       0.00    0.0000
# 7   2023-09-01     7       66.131  38830.40327       0.22    5.2668
# 8   2023-09-01     8       55.098  32302.48586       2.38   56.9772
# 9   2023-09-01     9       35.022  20475.68444       4.82  115.3908
# 10  2023-09-01    10       26.824  15681.65308       4.19  100.3086
# ...
